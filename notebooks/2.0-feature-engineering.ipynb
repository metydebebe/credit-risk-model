# %%
import sys
import os

# Adjust the path to your project root directory
project_root = os.path.abspath('..')  # assuming notebook is in notebooks/ folder
if project_root not in sys.path:
    sys.path.insert(0, project_root)

# Now you can import from src
from src.data_processing import process_data, categorical_cols, numerical_cols

# %%
# Import necessary libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Import your feature engineering pipeline function
from src.data_processing import process_data, categorical_cols, numerical_cols

# %%
# Load raw data
df = pd.read_csv('../data/raw/data.csv')

# %%
# Target variable
target = df['FraudResult']

# %%
print(df.columns)
# Out:
# Index(['TransactionId', 'BatchId', 'AccountId', 'SubscriptionId', 'CustomerId',
#        'CurrencyCode', 'CountryCode', 'ProviderId', 'ProductId',
#        'ProductCategory', 'ChannelId', 'Amount', 'Value',
#        'TransactionStartTime', 'PricingStrategy', 'FraudResult'],
#       dtype='object')

# %%
# Apply feature engineering pipeline (fit with target for WoE encoding)
X = process_data(df, target=target)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[11], line 2
#       1 # Apply feature engineering pipeline (fit with target for WoE encoding)
# ----> 2 X = process_data(df, target=target)
#
# File c:\Users\metya\Desktop\credit-risk-model\src\data_processing.py:112, in process_data(df, target)
#     110 # Fit the pipeline
#     111 if target is not None:
# --> 112     pipeline.fit(df, target)
#     113 else:
#     114     pipeline.fit(df)
#
# File c:\Users\metya\anaconda3\envs\credit-risk-model\Lib\site-packages\sklearn\base.py:1363, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1356     estimator._validate_params()
#    1358 with config_context(
#    1359     skip_parameter_validation=(
#    1360         prefer_skip_nested_validation or global_skip_validation
#    1361     )
#    1362 ):
# ...
